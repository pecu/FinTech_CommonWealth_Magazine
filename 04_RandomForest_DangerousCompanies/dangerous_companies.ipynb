# %%
# 讀取 CSV File
import pandas as pd # 引用套件並縮寫為 pd
df = pd.read_csv('xgboost.csv')

# %%
df.head(10)
# Out:
#         公司  PRO/NNOR (5)  PRO/NNOR (4)  PRO/NNOR (3)  PRO/NNOR (2)  \
# 0  1103 嘉泥        0.2182        0.1638        0.2493        0.2410
# 1  1109 信大        0.3982        0.3820        0.3651        0.3477
# 2  1109 信大        0.2701        0.2912        0.2734        0.2031
# 3  1109 信大        0.2912        0.2734        0.2031        0.1357
# 4  1109 信大        0.2734        0.2031        0.1357        0.2362
# 5  1109 信大        0.2031        0.1357        0.2362        0.2476
# 6  1113 永康        0.0000        0.0000        0.0000        0.0000
# 7  1203 味王        0.2363        0.2199        0.2178        0.2091
# 8  1206 台鳳        0.1451        0.1288        0.1196        0.1133
# 9  1206 台鳳        0.1196        0.1133        0.1989        0.1291
#
#    PRO/NNOR (1)  PRO/NNOR (0)  dangerous
# 0        0.2360        0.2651          0
# 1        0.3261        0.2701          0
# 2        0.1357        0.2362          0
# 3        0.2362        0.2476          0
# 4        0.2476        0.2832          0
# 5        0.2832        0.2612          0
# 6        0.0000        0.0000          1
# 7        0.2354        0.2603          1
# 8        0.1989        0.1291          1
# 9        0.1439        0.0268          1

# %%
X = df[['公司', 'PRO/NNOR (5)', 'PRO/NNOR (4)', 'PRO/NNOR (3)', 'PRO/NNOR (2)', 'PRO/NNOR (1)', 'PRO/NNOR (0)']]
y = df['dangerous']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25)

# %%
X_train.head(10)
# Out:
#            公司  PRO/NNOR (5)  PRO/NNOR (4)  PRO/NNOR (3)  PRO/NNOR (2)  \
# 559   5533 皇鼎        0.2398        0.2711        0.2408        0.1920
# 230   2028 威致        0.1508        0.1147        0.0267        0.0204
# 42    1324 地球        0.1656        0.1856        0.2189        0.2259
# 504  3055 蔚華科        0.2129        0.1749        0.2434        0.2202
# 323  2491 吉祥全        0.1186        0.2405        0.1948       -0.0897
# 416  2539 櫻花建        0.1405       -0.1250       -0.3267       -0.3364
# 254   2208 台船       -0.1313        0.0541        0.0841        0.0123
# 266   2342 茂矽        0.1050        0.1936        0.2157        0.0790
# 574   6176 瑞儀        0.1063        0.1164        0.1429        0.1364
# 43    1325 恒大        0.2838        0.1989        0.0004        0.1209
#
#      PRO/NNOR (1)  PRO/NNOR (0)
# 559        0.2027        0.0691
# 230        0.0396        0.0871
# 42         0.1518        0.1506
# 504        0.2123        0.2186
# 323       -0.0249       -0.1598
# 416       -0.3308        0.8643
# 254        0.0418        0.0679
# 266       -0.0441        0.1247
# 574        0.1234        0.1275
# 43        -0.0110        0.1372

# %%
X_train_NoName = X_train[['PRO/NNOR (5)', 'PRO/NNOR (4)', 'PRO/NNOR (3)', 'PRO/NNOR (2)', 'PRO/NNOR (1)', 'PRO/NNOR (0)']]

# %%
X_train_NoName.head(3)
# Out:
#      PRO/NNOR (5)  PRO/NNOR (4)  PRO/NNOR (3)  PRO/NNOR (2)  PRO/NNOR (1)  \
# 559        0.2398        0.2711        0.2408        0.1920        0.2027
# 230        0.1508        0.1147        0.0267        0.0204        0.0396
# 42         0.1656        0.1856        0.2189        0.2259        0.1518
#
#      PRO/NNOR (0)
# 559        0.0691
# 230        0.0871
# 42         0.1506

# %%
from sklearn.ensemble import RandomForestClassifier
rfc = RandomForestClassifier(max_depth = 3, n_estimators = 10)
rfc.fit(X_train_NoName, y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=3, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=None,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)

# %%
X_test_NoName = X_test[['PRO/NNOR (5)', 'PRO/NNOR (4)', 'PRO/NNOR (3)', 'PRO/NNOR (2)', 'PRO/NNOR (1)', 'PRO/NNOR (0)']]

# %%
X_test_NoName.head(3)
# Out:
#      PRO/NNOR (5)  PRO/NNOR (4)  PRO/NNOR (3)  PRO/NNOR (2)  PRO/NNOR (1)  \
# 85         0.0448        0.1088        0.0271       -0.1132       -0.1124
# 185       -0.4363        0.0275       -0.4945        0.1395        0.4309
# 470        0.4535        0.4246        0.3777        0.4132        0.3673
#
#      PRO/NNOR (0)
# 85         0.0074
# 185        0.2795
# 470        0.3796

# %%
print('The accuracy of Random Forest Classifier on testing set:', rfc.score(X_test_NoName, y_test))
# Out:
# The accuracy of Random Forest Classifier on testing set: 0.6829268292682927

# %%
testResults = rfc.predict(X_test_NoName)

# %%
X_test['預測'] = testResults
X_test['真實'] = y_test
# Out:
# C:\Users\pecu6\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\pecu6\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
X_test['不同'] = X_test['預測'] - X_test['真實']
# Out:
# C:\Users\pecu6\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
X_test.loc[X_test['不同'] != 0]
# Out:
#                公司  PRO/NNOR (5)  PRO/NNOR (4)  PRO/NNOR (3)  PRO/NNOR (2)  \
# 595       8105 凌巨        0.0231        0.0430        0.0178        0.0646
# 591    8028 昇陽半導體        0.0000        0.0000        0.3233        0.3926
# 169     1801 志富國際        0.5489        0.3706        0.4431        0.4756
# 284       2358 廷鑫        0.0689        0.0099        0.0287        0.0527
# 305       2430 燦坤        0.2212        0.2072        0.1789        0.1878
# 155       1615 大山        0.0629        0.0672        0.0948        0.0473
# 589      6464 台數科        0.5476        0.5438        0.5760        0.5428
# 538       4424 民興        0.1644        0.2053        0.1619        0.1148
# 373       2524 京城        0.0758        0.1576       -0.0019       -0.0359
# 260       2331 精英        0.1207        0.0957        0.0597        0.0770
# 437       2546 根基        0.0588        0.0512        0.0398        0.0282
# 231       2028 威致        0.0871        0.0914        0.0968        0.0452
# 474      3004 豐達科        0.3746        0.2790        0.2092        0.1924
# 364       2521 宏總        0.0188        0.0920        0.1691        0.1260
# 291       2388 威盛        0.4261        0.4165        0.3949        0.3369
# 299       2424 隴華       -0.0131       -0.0967        0.0070        0.0827
# 161       1618 合機        0.1447        0.0628        0.0820        0.0555
# 604       8464 億豐        0.0000        0.0000        0.3505        0.3669
# 239       2101 南港        0.1946        0.2060        0.2389        0.2326
# 344       2506 太設        0.1968        0.1958        0.2562        0.2168
# 537       4424 民興        0.0563        0.1644        0.2053        0.1619
# 535       4414 如興        0.0149        0.1348        0.1389        0.1390
# 606  9103 美德醫療-DR        0.1999        0.1662        0.1491        0.1603
# 36        1312 國喬       -0.0099        0.0785        0.0751        0.0198
# 158       1617 榮星        0.0599        0.0450        0.0191        0.0372
# 321      2491 吉祥全        0.0186        0.1902        0.2588        0.2172
# 105       1516 川飛        0.0808       -0.0318       -0.0050        0.0194
# 40        1316 上曜        0.0105        0.0778        0.0636        0.0702
# 304      2429 銘旺科       -0.0889       -0.1856        0.0433       -0.0200
# 314       2450 神腦        0.0917        0.0784        0.0951        0.1076
# 264       2337 旺宏        0.3635        0.0993        0.0879        0.1291
# 338       2506 太設        0.1793        0.1685        0.0459       -0.0527
# 400       2536 宏普        0.2187        0.1778        0.0038       -0.0019
# 214      2016 名佳利        0.1339        0.1555        0.0939        0.1382
# 378       2527 宏璟        0.2176       -0.3539        0.0165        0.1749
# 119       1604 聲寶        0.1624        0.1701        0.1490        0.0941
# 136       1608 華榮        0.1158        0.0955        0.0566        0.0729
# 443       2566 復木        0.2616        0.0586        0.1611        0.1254
# 572       6172 互億        0.0975        0.0852        0.0847        0.0093
# 561       5533 皇鼎        0.2408        0.1920        0.2027        0.0691
# 354       2515 中工       -0.0553       -0.0804        0.0193       -0.0462
# 356       2515 中工        0.0193       -0.0462        0.0227        0.0333
# 21        1221 久津        0.1436        0.1914        0.1782        0.2482
# 394       2530 華建        0.2651        0.1239        0.1169        0.0328
# 176       1805 寶徠       -0.0026        0.0479        0.1133       -0.0279
# 396       2534 宏盛       -0.0409       -0.0472        0.0090        0.2451
# 614       9902 台火        0.1117        0.0575        0.1162        0.1674
# 18        1221 久津        0.2536        0.1645        0.1218        0.1436
# 408      2537 聯上發       -0.3218       -0.2699       -2.9326       -1.0566
# 248     2206 三陽工業        0.0946        0.1008        0.0954        0.1486
# 142       1609 大亞        0.1464        0.0921        0.1066        0.0730
# 285       2361 鴻友        0.1206        0.1243        0.1252        0.1216
#
#      PRO/NNOR (1)  PRO/NNOR (0)  預測  真實  不同
# 595        0.1127        0.1483   1   0   1
# 591        0.4465        0.4268   0   1  -1
# 169        0.7385        0.9315   0   1  -1
# 284        0.0419        0.0345   1   0   1
# 305        0.1523        0.0616   0   1  -1
# 155        0.0552        0.0474   1   0   1
# 589        0.5062        0.4690   0   1  -1
# 538        0.0992        0.1275   0   1  -1
# 373       -0.0034        0.0833   1   0   1
# 260        0.1119        0.0496   1   0   1
# 437        0.0380        0.0015   1   0   1
# 231        0.0870        0.0851   0   1  -1
# 474        0.2416        0.1222   0   1  -1
# 364        0.1815        0.4450   0   1  -1
# 291        0.3167        0.2680   0   1  -1
# 299        0.2308        0.1431   1   0   1
# 161       -0.0186        0.0707   1   0   1
# 604        0.3950        0.4151   0   1  -1
# 239        0.1614        0.1690   0   1  -1
# 344        0.2391        0.2658   0   1  -1
# 537        0.1148        0.0992   0   1  -1
# 535        0.1454        0.1479   0   1  -1
# 606        0.1606        0.1565   0   1  -1
# 36         0.1697        0.1319   1   0   1
# 158        0.0835        0.0413   1   0   1
# 321        0.1186        0.2405   0   1  -1
# 105        0.0138        0.0341   1   0   1
# 40         0.1124        0.1377   0   1  -1
# 304       -0.0397       -0.0011   1   0   1
# 314        0.1455        0.1608   0   1  -1
# 264        0.1200        0.2419   0   1  -1
# 338        0.1511        0.2727   0   1  -1
# 400       -0.2418        0.2766   1   0   1
# 214        0.0656        0.1190   0   1  -1
# 378        0.1055        0.1906   1   0   1
# 119        0.0430        0.0904   0   1  -1
# 136        0.0807        0.0347   1   0   1
# 443       -3.7313        0.0000   1   0   1
# 572       -0.0852        0.0744   1   0   1
# 561       -0.0149        0.1322   1   0   1
# 354        0.0227        0.0333   1   0   1
# 356        0.0373        0.0472   1   0   1
# 21         0.2412        0.2158   0   1  -1
# 394        0.0506        0.1752   0   1  -1
# 176        0.0411        0.0449   1   0   1
# 396        0.2649        0.3460   1   0   1
# 614        0.4305        0.3682   0   1  -1
# 18         0.1914        0.1782   0   1  -1
# 408        0.1621        0.1318   1   0   1
# 248        0.1771        0.2276   0   1  -1
# 142        0.0618        0.0320   1   0   1
# 285        0.1255        0.0601   0   1  -1

# %%
X_test.loc[X_test['不同'] == 0]
# Out:
#            公司  PRO/NNOR (5)  PRO/NNOR (4)  PRO/NNOR (3)  PRO/NNOR (2)  \
# 85    1450 新藝        0.0448        0.1088        0.0271       -0.1132
# 185   1808 潤隆       -0.4363        0.0275       -0.4945        0.1395
# 470  2911 麗嬰房        0.4535        0.4246        0.3777        0.4132
# 486   3031 佰鴻        0.2231        0.2242        0.2494        0.1730
# 25   1231 聯華食        0.3749        0.3954        0.3771        0.2872
# 302  2429 銘旺科        0.0406        0.0398        0.0253       -0.0648
# 452   2610 華航        0.1703        0.1555        0.1412        0.0413
# 210  2013 中鋼構        0.0711        0.0609        0.0684        0.0875
# 513   3164 景岳        0.7646        0.6701        0.6355        0.6928
# 563   5534 長虹       -0.4405        0.2619        0.5798        0.1566
# 411  2539 櫻花建        0.2708        0.2375        0.1938        0.1510
# 568   6139 亞翔        0.2203        0.1698        0.1759        0.2120
# 222   2024 志聯        0.0425        0.0455        0.0344       -0.0359
# 326  2494 廣業科        0.1335        0.0582       -0.0301       -0.0600
# 353   2512 寶建        0.2090        0.2164        0.1236       -0.0712
# 601   8341 日友        0.4250        0.4302        0.4312        0.4213
# 430  2540 愛山林        0.8600        0.0237        0.1251        0.0752
# 582   6225 天瀚        0.2334        0.1865        0.1788        0.1404
# 422  2540 愛山林        0.1230        0.0728       -0.2066        0.0721
# 211  2013 中鋼構        0.0609        0.0684        0.0875        0.0941
# 653   9955 佳龍        0.3261        0.2008        0.1647        0.1627
# 367   2523 德寶       -0.6669       -0.4853       -0.0357        0.0623
# 145   1613 台一        0.0849        0.0716       -0.0036       -0.0522
# 196   1918 萬有        0.1981        0.0910        0.0576        0.1065
# 132   1606 歌林        0.1582        0.1768        0.2056        0.1624
# 540   4424 民興        0.1148        0.0992        0.1275       -0.0136
# 53    1431 新燕        0.1339        0.2115        0.2200        0.1471
# 258   2325 矽品        0.2934        0.2075        0.1930        0.1537
# 406  2537 聯上發       -0.0918       -0.1492       -0.3218       -0.2699
# 194   1906 寶隆        0.0838        0.0530        0.1165        0.1275
# ..        ...           ...           ...           ...           ...
# 519   3346 麗清        0.2234        0.1996        0.2226        0.1650
# 546   5007 三星        0.1726        0.1542        0.2017        0.1280
# 451   2607 榮運        0.1354        0.0491        0.1681        0.1687
# 454   2841 台開        0.2538        0.0000        0.1211       -0.1563
# 74    1442 名軒        0.2082       -0.0907        0.0490        0.0103
# 253  2207 和泰車        0.0717        0.0634        0.0710        0.0699
# 420  2540 愛山林        0.1974        0.2159        0.1230        0.0728
# 126   1606 歌林        0.1265       -0.3051       -0.4043        0.0424
# 310   2438 翔耀        0.1196        0.0005       -0.1214       -0.0170
# 202   1918 萬有        0.0648       -0.0724       -0.0246       -0.0073
# 259   2329 華泰        0.1025        0.1020       -0.1252       -0.0908
# 392   2530 華建        0.1789        0.4013        0.2651        0.1239
# 122   1604 聲寶        0.1779        0.1915        0.1868        0.2162
# 267   2342 茂矽        0.1936        0.2157        0.0790       -0.0441
# 457   2841 台開       -0.1563       -0.4153        0.0906       -0.2255
# 348  2509 全坤建        0.1087        0.0548        0.2636        0.3651
# 375   2525 寶祥        0.3599        0.0453        0.2926       -2.2551
# 349  2509 全坤建        0.2636        0.3651        0.3231        0.1034
# 88    1456 怡華        0.0455        0.0903        0.0693        0.0258
# 320   2488 漢平        0.2726        0.2373        0.2327        0.2564
# 47    1417 嘉裕        0.2166        0.3388        0.3305        0.3539
# 30    1236 宏亞        0.3516        0.3818        0.3832        0.3664
# 204   1918 萬有       -0.0246       -0.0073       -0.0035        0.0099
# 650   9942 茂順        0.3280        0.3429        0.3346        0.3318
# 172   1805 寶徠        0.1132        0.1336        0.1318        0.0815
# 350   2511 太子        0.2944        0.3555        0.3498        0.2825
# 10   1207 嘉食化        0.0376        0.0279        0.0172        0.0536
# 4     1109 信大        0.2734        0.2031        0.1357        0.2362
# 433  2542 興富發        0.0314        0.0773        0.1493        0.2147
# 90    1456 怡華        0.0693        0.0258        0.0155        0.0098
#
#      PRO/NNOR (1)  PRO/NNOR (0)  預測  真實  不同
# 85        -0.1124        0.0074   1   1   0
# 185        0.4309        0.2795   1   1   0
# 470        0.3673        0.3796   0   0   0
# 486        0.1674        0.1888   0   0   0
# 25         0.2689        0.2489   0   0   0
# 302        0.0706        0.0459   1   1   0
# 452        0.0858        0.1833   0   0   0
# 210        0.0941        0.0805   0   0   0
# 513        0.4488        0.5111   0   0   0
# 563        0.1492        0.2459   0   0   0
# 411        0.1405       -0.1250   1   1   0
# 568        0.1318        0.0994   0   0   0
# 222        0.0425        0.0419   1   1   0
# 326        0.0047        0.0033   1   1   0
# 353        0.0895        0.0732   1   1   0
# 601        0.4087        0.4310   0   0   0
# 430        0.0191        0.2478   1   1   0
# 582        0.0030        0.1043   0   0   0
# 422       -0.0671       -0.2247   1   1   0
# 211        0.0805        0.0894   0   0   0
# 653        0.1220        0.1112   0   0   0
# 367        0.1559        0.1983   1   1   0
# 145       -0.0188        0.0288   1   1   0
# 196       -0.0023       -0.0146   1   1   0
# 132        0.1735        0.2561   0   0   0
# 540       -0.0105       -0.0408   1   1   0
# 53        -0.0592       -0.1185   1   1   0
# 258        0.1550        0.1816   0   0   0
# 406       -2.9326       -1.0566   1   1   0
# 194        0.1317        0.1198   0   0   0
# ..            ...           ...  ..  ..  ..
# 519        0.1991        0.1931   0   0   0
# 546        0.1009        0.1491   0   0   0
# 451        0.1735        0.1577   0   0   0
# 454       -0.4153        0.0906   1   1   0
# 74        -0.0654       -0.0154   1   1   0
# 253        0.0758        0.0789   0   0   0
# 420       -0.2066        0.0721   1   1   0
# 126        0.0088        0.0872   1   1   0
# 310        0.0546       -0.6649   1   1   0
# 202       -0.0035        0.0099   1   1   0
# 259       -0.0835       -0.0329   1   1   0
# 392        0.1169        0.0328   1   1   0
# 122        0.2353        0.2547   0   0   0
# 267        0.1247       -0.1296   1   1   0
# 457        0.1750       -1.6358   1   1   0
# 348        0.3231        0.1034   0   0   0
# 375        0.5399       -0.7334   1   1   0
# 349        0.0333        0.3006   0   0   0
# 88         0.0155        0.0098   1   1   0
# 320        0.2074        0.2338   0   0   0
# 47         0.4028        0.3765   0   0   0
# 30         0.3026        0.3587   0   0   0
# 204        0.1008       -0.0281   1   1   0
# 650        0.3238        0.3009   0   0   0
# 172       -0.1755        0.1649   1   1   0
# 350        0.2169        0.0994   0   0   0
# 10        -0.0055       -0.0310   1   1   0
# 4          0.2476        0.2832   0   0   0
# 433        0.2611        0.2814   0   0   0
# 90         0.0083       -0.0539   1   1   0
#
# [112 rows x 10 columns]

# %%
# Extract single tree
estimator_limited = rfc.estimators_[9]

from sklearn.tree import export_graphviz
export_graphviz(estimator_limited, out_file='tree_limited.dot', feature_names = X_train_NoName.columns,
                class_names = [str(i) for i in y_test.unique()],
                rounded = True, proportion = False, precision = 2, filled = True)

# %%
from IPython.display import Image
Image(filename = 'tree_limited.png')

# %%
from xgboost import XGBClassifier

# %%
xgbc = XGBClassifier()
xgbc.fit(X_train_NoName, y_train)
# Out:
# XGBClassifier(base_score=0.5, colsample_bylevel=1, colsample_bytree=1,
#        gamma=0, learning_rate=0.1, max_delta_step=0, max_depth=3,
#        min_child_weight=1, missing=None, n_estimators=100, nthread=-1,
#        objective='binary:logistic', reg_alpha=0, reg_lambda=1,
#        scale_pos_weight=1, seed=0, silent=True, subsample=1)

# %%
print('The accuracy of eXtreme Gradient Boosting Classifier on testing set:', xgbc.score(X_test_NoName, y_test))
# Out:
# The accuracy of eXtreme Gradient Boosting Classifier on testing set: 0.6829268292682927
