# %%
# 讀取 CSV File
import pandas as pd # 引用套件並縮寫為 pd
df = pd.read_csv('xgboost.csv')

# %%
df.head(10)
# Out:
#         公司  PRO/NNOR (5)  PRO/NNOR (4)  PRO/NNOR (3)  PRO/NNOR (2)  \
# 0  1103 嘉泥        0.2182        0.1638        0.2493        0.2410
# 1  1109 信大        0.3982        0.3820        0.3651        0.3477
# 2  1109 信大        0.2701        0.2912        0.2734        0.2031
# 3  1109 信大        0.2912        0.2734        0.2031        0.1357
# 4  1109 信大        0.2734        0.2031        0.1357        0.2362
# 5  1109 信大        0.2031        0.1357        0.2362        0.2476
# 6  1113 永康        0.0000        0.0000        0.0000        0.0000
# 7  1203 味王        0.2363        0.2199        0.2178        0.2091
# 8  1206 台鳳        0.1451        0.1288        0.1196        0.1133
# 9  1206 台鳳        0.1196        0.1133        0.1989        0.1291
#
#    PRO/NNOR (1)  PRO/NNOR (0)  dangerous
# 0        0.2360        0.2651          0
# 1        0.3261        0.2701          0
# 2        0.1357        0.2362          0
# 3        0.2362        0.2476          0
# 4        0.2476        0.2832          0
# 5        0.2832        0.2612          0
# 6        0.0000        0.0000          1
# 7        0.2354        0.2603          1
# 8        0.1989        0.1291          1
# 9        0.1439        0.0268          1

# %%
X = df[['公司', 'PRO/NNOR (5)', 'PRO/NNOR (4)', 'PRO/NNOR (3)', 'PRO/NNOR (2)', 'PRO/NNOR (1)', 'PRO/NNOR (0)']]
y = df['dangerous']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25)

# %%
X_train.head(10)
# Out:
#            公司  PRO/NNOR (5)  PRO/NNOR (4)  PRO/NNOR (3)  PRO/NNOR (2)  \
# 224   2024 志聯        0.0344       -0.0359        0.0425        0.0419
# 486   3031 佰鴻        0.2231        0.2242        0.2494        0.1730
# 368   2523 德寶       -0.4853       -0.0357        0.0623        0.1559
# 185   1808 潤隆       -0.4363        0.0275       -0.4945        0.1395
# 223   2024 志聯        0.0455        0.0344       -0.0359        0.0425
# 587   6289 華上       -0.7384       -0.9116       -1.6118       -1.8438
# 41    1323 永裕        0.2537        0.2579        0.2767        0.2457
# 624  9906 欣巴巴        0.0740        0.0597        0.0606        0.1185
# 42    1324 地球        0.1656        0.1856        0.2189        0.2259
# 422  2540 愛山林        0.1230        0.0728       -0.2066        0.0721
#
#      PRO/NNOR (1)  PRO/NNOR (0)
# 224        0.1218        0.0407
# 486        0.1674        0.1888
# 368        0.1983        0.1151
# 185        0.4309        0.2795
# 223        0.0419        0.1218
# 587       -0.8469       -0.8374
# 41         0.2360        0.2313
# 624        0.0844        0.0481
# 42         0.1518        0.1506
# 422       -0.0671       -0.2247

# %%
X_train_NoName = X_train[['PRO/NNOR (5)', 'PRO/NNOR (4)', 'PRO/NNOR (3)', 'PRO/NNOR (2)', 'PRO/NNOR (1)', 'PRO/NNOR (0)']]

# %%
X_train_NoName.head(3)
# Out:
#      PRO/NNOR (5)  PRO/NNOR (4)  PRO/NNOR (3)  PRO/NNOR (2)  PRO/NNOR (1)  \
# 224        0.0344       -0.0359        0.0425        0.0419        0.1218
# 486        0.2231        0.2242        0.2494        0.1730        0.1674
# 368       -0.4853       -0.0357        0.0623        0.1559        0.1983
#
#      PRO/NNOR (0)
# 224        0.0407
# 486        0.1888
# 368        0.1151

# %%
from sklearn.ensemble import RandomForestClassifier
rfc = RandomForestClassifier(max_depth = 3, n_estimators = 10)
rfc.fit(X_train_NoName, y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=3, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=None,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)

# %%
X_test_NoName = X_test[['PRO/NNOR (5)', 'PRO/NNOR (4)', 'PRO/NNOR (3)', 'PRO/NNOR (2)', 'PRO/NNOR (1)', 'PRO/NNOR (0)']]

# %%
X_test_NoName.head(3)
# Out:
#      PRO/NNOR (5)  PRO/NNOR (4)  PRO/NNOR (3)  PRO/NNOR (2)  PRO/NNOR (1)  \
# 3          0.2912        0.2734        0.2031        0.1357        0.2362
# 324        0.1948       -0.0897       -0.0249       -0.1598       -0.1844
# 414        0.1510        0.1405       -0.1250       -0.3267       -0.3364
#
#      PRO/NNOR (0)
# 3          0.2476
# 324       -0.1417
# 414       -0.3308

# %%
print('The accuracy of Random Forest Classifier on testing set:', rfc.score(X_test_NoName, y_test))
# Out:
# The accuracy of Random Forest Classifier on testing set: 0.6707317073170732

# %%
testResults = rfc.predict(X_test_NoName)

# %%
X_test['預測'] = testResults
X_test['真實'] = y_test
# Out:
# C:\Users\pecu6\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\pecu6\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
X_test['不同'] = X_test['預測'] - X_test['真實']
# Out:
# C:\Users\pecu6\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
X_test.loc[X_test['不同'] != 0]
# Out:
#             公司  PRO/NNOR (5)  PRO/NNOR (4)  PRO/NNOR (3)  PRO/NNOR (2)  \
# 248  2206 三陽工業        0.0946        0.1008        0.0954        0.1486
# 210   2013 中鋼構        0.0711        0.0609        0.0684        0.0875
# 19     1221 久津        0.1645        0.1218        0.1436        0.1914
# 151    1613 台一        0.0288        0.0323        0.0261        0.0245
# 475   3004 豐達科        0.2790        0.2092        0.1924        0.2416
# 158    1617 榮星        0.0599        0.0450        0.0191        0.0372
# 408   2537 聯上發       -0.3218       -0.2699       -2.9326       -1.0566
# 569    6165 捷泰        0.1409        0.0726        0.0418        0.0724
# 188    1903 士紙        0.1335        0.0077        0.0976        0.1201
# 70     1438 裕豐        0.0104        0.0057        0.2341        0.5114
# 572    6172 互億        0.0975        0.0852        0.0847        0.0093
# 636    9922 優美        0.2958        0.2907        0.2827        0.2578
# 49     1418 東華       -0.0145        0.0027       -0.0882        0.1426
# 495    3049 和鑫        0.0890       -0.1193        0.0785        0.1621
# 36     1312 國喬       -0.0099        0.0785        0.0751        0.0198
# 633    9922 優美        0.2948        0.2679        0.2663        0.2958
# 354    2515 中工       -0.0553       -0.0804        0.0193       -0.0462
# 108    1526 日馳        0.0023        0.0712        0.1604        0.1620
# 490    3040 遠見        0.2873        0.2776        0.2453        0.0934
# 583    6235 華孚        0.1252        0.1062        0.0786        0.0627
# 18     1221 久津        0.2536        0.1645        0.1218        0.1436
# 355    2515 中工       -0.0553       -0.0804        0.0193       -0.0462
# 388    2528 皇普       -0.5003       -0.8267       -1.2248        0.4446
# 476   3004 豐達科        0.2092        0.1924        0.2416        0.1222
# 78     1446 宏和        0.1425        0.1438        0.1340        0.1121
# 215   2016 名佳利        0.1555        0.0939        0.1382        0.0656
# 436    2546 根基        0.0588        0.0512        0.0398        0.0282
# 342    2506 太設        0.1511        0.2727        0.1968        0.1958
# 46     1416 廣豐        0.0446        0.0976        0.0360        0.0295
# 192    1905 華紙        0.0801        0.0259        0.1690        0.2447
# 239    2101 南港        0.1946        0.2060        0.2389        0.2326
# 560    5533 皇鼎        0.2408        0.1920        0.2027        0.0691
# 437    2546 根基        0.0588        0.0512        0.0398        0.0282
# 238    2034 允強        0.1381        0.1169        0.1229        0.1080
# 509    3061 璨圓        0.5898        0.5307        0.4034        0.4076
# 372    2524 京城        0.2068        0.1450        0.0625        0.0758
# 399    2536 宏普        0.2919        0.3435        0.3368        0.2187
# 448    2566 復木       -3.7313        0.0000        0.0000        0.0000
# 227    2024 志聯        0.0407        0.0660        0.0655        0.1031
# 379    2527 宏璟       -0.3539        0.0165        0.1749        0.1055
# 427   2540 愛山林       -0.2247        0.9145        0.8503        0.8600
# 400    2536 宏普        0.2187        0.1778        0.0038       -0.0019
# 95   1470 大統新創        0.0915        0.0579        0.0942        0.0531
# 59     1435 中福        0.0023       -0.0275        0.0385        0.0425
# 329    2504 國產        0.0700        0.0667        0.0541        0.0567
# 189    1903 士紙        0.0077        0.0976        0.1201       -0.0490
# 253   2207 和泰車        0.0717        0.0634        0.0710        0.0699
# 566    6120 達運        0.1629        0.1238        0.0872        0.0445
# 445    2566 復木        0.1611        0.1254       -3.7313        0.0000
# 247  2206 三陽工業        0.1203        0.0946        0.1008        0.0954
# 359    2518 長億        0.2519        0.2834        0.2385        0.2390
# 105    1516 川飛        0.0808       -0.0318       -0.0050        0.0194
# 159    1617 榮星        0.0372        0.0835        0.0413        0.0479
# 142    1609 大亞        0.1464        0.0921        0.1066        0.0730
#
#      PRO/NNOR (1)  PRO/NNOR (0)  預測  真實  不同
# 248        0.1771        0.2276   0   1  -1
# 210        0.0941        0.0805   1   0   1
# 19         0.1782        0.2482   0   1  -1
# 151        0.0055        0.0290   1   0   1
# 475        0.1222        0.1241   0   1  -1
# 158        0.0835        0.0413   1   0   1
# 408        0.1621        0.1318   1   0   1
# 569        0.2108        0.2295   0   1  -1
# 188       -0.0490        0.0344   1   0   1
# 70         0.4801        0.5816   1   0   1
# 572       -0.0852        0.0744   1   0   1
# 636        0.2665        0.2550   0   1  -1
# 49         0.0562        0.0501   1   0   1
# 495       -0.1350        0.0855   1   0   1
# 36         0.1697        0.1319   1   0   1
# 633        0.2907        0.2827   0   1  -1
# 354        0.0227        0.0333   1   0   1
# 108        0.1647        0.1938   1   0   1
# 490        0.2324        0.2517   1   0   1
# 583        0.1657        0.1775   0   1  -1
# 18         0.1914        0.1782   0   1  -1
# 355        0.0227        0.0333   1   0   1
# 388        0.1305        0.1272   0   1  -1
# 476        0.1241        0.2526   0   1  -1
# 78         0.0388        0.0696   1   0   1
# 215        0.1190        0.1560   0   1  -1
# 436        0.0380        0.0015   1   0   1
# 342        0.2562        0.2168   0   1  -1
# 46         0.0034        0.0035   1   0   1
# 192        0.0202        0.1713   1   0   1
# 239        0.1614        0.1690   0   1  -1
# 560       -0.0149        0.1322   1   0   1
# 437        0.0380        0.0015   1   0   1
# 238        0.0542        0.1084   1   0   1
# 509        0.1761        0.0606   1   0   1
# 372        0.1576       -0.0019   1   0   1
# 399        0.1778        0.0038   1   0   1
# 448        0.0000        0.0000   1   0   1
# 227       -0.0991        0.1143   1   0   1
# 379        0.1906        0.1270   1   0   1
# 427        0.0237        0.1251   0   1  -1
# 400       -0.2418        0.2766   1   0   1
# 95         0.0262        0.0707   1   0   1
# 59         0.3701        0.2943   1   0   1
# 329        0.1111        0.1301   1   0   1
# 189        0.0344       -0.0261   1   0   1
# 253        0.0758        0.0789   1   0   1
# 566        0.0019        0.0897   1   0   1
# 445        0.0000        0.0000   1   0   1
# 247        0.1486        0.1771   0   1  -1
# 359        0.1420        0.0766   0   1  -1
# 105        0.0138        0.0341   1   0   1
# 159        0.0653        0.0840   1   0   1
# 142        0.0618        0.0320   1   0   1

# %%
X_test.loc[X_test['不同'] == 0]
# Out:
#               公司  PRO/NNOR (5)  PRO/NNOR (4)  PRO/NNOR (3)  PRO/NNOR (2)  \
# 3        1109 信大        0.2912        0.2734        0.2031        0.1357
# 324     2491 吉祥全        0.1948       -0.0897       -0.0249       -0.1598
# 414     2539 櫻花建        0.1510        0.1405       -0.1250       -0.3267
# 527     3535 晶彩科        0.2694        0.2055        0.3618        0.3885
# 652      9942 茂順        0.3262        0.3469        0.3685        0.3703
# 419     2539 櫻花建       -0.3267       -0.3364       -0.3308        0.8643
# 66       1438 裕豐        0.0108        0.0155        0.0037        0.0104
# 137      1609 大亞        0.1328        0.1075        0.1209        0.0936
# 273      2342 茂矽       -0.4019       -0.4542       -0.3196       -0.2137
# 429     2540 愛山林        0.8503        0.8600        0.0237        0.1251
# 346      2506 太設        0.2630        0.2250        0.1619        0.2133
# 65       1438 裕豐        0.2239        0.0108        0.0155        0.0037
# 124      1606 歌林        0.2561        0.1525        0.1265       -0.3051
# 594      8078 華寶        0.1562        0.1126        0.1098        0.1095
# 420     2540 愛山林        0.1974        0.2159        0.1230        0.0728
# 64       1438 裕豐       -0.1929        0.0489        0.2239        0.0108
# 562      5533 皇鼎        0.1920        0.2027        0.0691       -0.0149
# 116      1602 太電        0.0786        0.0944        0.0979        0.0644
# 605    8478 東哥遊艇        0.1396        0.1818        0.2106        0.3020
# 139      1609 大亞        0.1209        0.0936        0.1464        0.0921
# 519      3346 麗清        0.2234        0.1996        0.2226        0.1650
# 403     2537 聯上發       -0.1311        0.1315       -0.0938       -0.0918
# 236      2033 佳大        0.1507        0.1910        0.1219        0.1199
# 297      2418 雅新        0.2061        0.1880        0.0091       -0.0549
# 565      6116 彩晶       -0.0075        0.0755        0.2993        0.1852
# 67       1438 裕豐        0.0155        0.0037        0.0104        0.0057
# 222      2024 志聯        0.0425        0.0455        0.0344       -0.0359
# 245      2202 三富        0.0006        0.0578       -0.0997        0.0105
# 558      5525 順天        0.2387        0.1346        0.2298        0.1787
# 499      3051 力特        0.0489       -0.0399       -0.2700        0.0483
# ..           ...           ...           ...           ...           ...
# 571      6172 互億        0.0852        0.0847        0.0093       -0.0852
# 244      2202 三富        0.0650        0.0006        0.0578       -0.0997
# 462      2902 中信        0.0796        0.1078        0.0633       -0.0138
# 435      2545 皇翔        0.2112        0.2208        0.3258        0.3656
# 353      2512 寶建        0.2090        0.2164        0.1236       -0.0712
# 60       1438 裕豐        0.1514        0.0149       -0.0359       -0.0897
# 27      1231 聯華食        0.3771        0.2872        0.2689        0.2489
# 51       1424 新東       -0.5428       -0.1919        0.0131        0.0195
# 651      9942 茂順        0.3429        0.3346        0.3318        0.3238
# 389      2528 皇普        0.1305        0.1272        0.5139        0.0392
# 183      1808 潤隆       -0.1068       -0.1236       -0.4363        0.0275
# 111      1602 太電        0.1363        0.1099        0.0972        0.1003
# 34       1310 台苯        0.0838        0.0228       -0.0001       -0.0033
# 122      1604 聲寶        0.1779        0.1915        0.1868        0.2162
# 138      1609 大亞        0.1075        0.1209        0.0936        0.1464
# 181      1808 潤隆        0.0360        0.0558       -0.1068       -0.1236
# 434      2545 皇翔        0.1636        0.2036        0.2076        0.2290
# 277      2348 海悅        0.0046        0.0037        0.0085        0.0143
# 25      1231 聯華食        0.3749        0.3954        0.3771        0.2872
# 383      2528 皇普        0.1757        0.1498        0.0784       -0.0089
# 497      3051 力特        0.1755        0.0918        0.0489       -0.0399
# 536      4424 民興       -0.0011       -0.0941       -0.0204       -0.0540
# 467      2904 匯僑        0.1247        0.1259        0.1175        0.1829
# 611  9110 越南控-DR        0.1093        0.0776        0.0670        0.0723
# 141      1609 大亞        0.0936        0.1464        0.0921        0.1066
# 40       1316 上曜        0.0105        0.0778        0.0636        0.0702
# 38      1314 中石化        0.0400        0.0207        0.0661       -0.0575
# 438     2547 日勝生        0.2694        0.3421        0.4582        0.4718
# 456      2841 台開        0.1211       -0.1563       -0.4153        0.0906
# 485      3025 星通        0.3842        0.4332        0.4405        0.4585
#
#      PRO/NNOR (1)  PRO/NNOR (0)  預測  真實  不同
# 3          0.2362        0.2476   0   0   0
# 324       -0.1844       -0.1417   1   1   0
# 414       -0.3364       -0.3308   1   1   0
# 527        0.3728        0.4668   0   0   0
# 652        0.3420        0.3628   0   0   0
# 419        0.3763        0.1674   0   0   0
# 66         0.0057        0.2341   1   1   0
# 137        0.1464        0.0921   0   0   0
# 273        0.1678        0.1686   1   1   0
# 429        0.0752        0.0191   1   1   0
# 346        0.1839        0.1793   0   0   0
# 65         0.0104        0.0057   1   1   0
# 124       -0.4043        0.0424   1   1   0
# 594        0.1021        0.1240   0   0   0
# 420       -0.2066        0.0721   1   1   0
# 64         0.0155        0.0037   1   1   0
# 562        0.1322        0.1708   0   0   0
# 116        0.0037        0.1109   1   1   0
# 605        0.2850        0.3055   0   0   0
# 139        0.1066        0.0730   0   0   0
# 519        0.1991        0.1931   0   0   0
# 403       -0.1492       -0.3218   1   1   0
# 236        0.1121        0.2494   0   0   0
# 297       -0.4287       -0.2564   1   1   0
# 565        0.0004        0.2920   1   1   0
# 67         0.2341        0.5114   1   1   0
# 222        0.0425        0.0419   1   1   0
# 245        0.0052       -0.1581   1   1   0
# 558        0.2739        0.2356   0   0   0
# 499        0.0065        0.1142   1   1   0
# ..            ...           ...  ..  ..  ..
# 571        0.0744        0.0347   1   1   0
# 244        0.0105        0.0052   1   1   0
# 462       -0.0875       -0.3031   1   1   0
# 435        0.3904        0.3813   0   0   0
# 353        0.0895        0.0732   1   1   0
# 60        -0.1929        0.0489   1   1   0
# 27         0.2581        0.2633   0   0   0
# 51         0.0537        0.0405   1   1   0
# 651        0.3009        0.3295   0   0   0
# 389        0.6823        0.1988   0   0   0
# 183       -0.4945        0.1395   1   1   0
# 111       -0.6422        0.0716   1   1   0
# 34         0.0696       -0.0086   1   1   0
# 122        0.2353        0.2547   0   0   0
# 138        0.0921        0.1066   0   0   0
# 181       -0.4363        0.0275   1   1   0
# 434        0.1907        0.1593   0   0   0
# 277        0.0160        0.0190   1   1   0
# 25         0.2689        0.2489   0   0   0
# 383       -0.2586       -0.5447   1   1   0
# 497       -0.2700        0.0483   1   1   0
# 536        0.0268        0.0563   1   1   0
# 467        0.1328        0.0662   0   0   0
# 611        0.1181        0.0647   0   0   0
# 141        0.0730        0.0618   0   0   0
# 40         0.1124        0.1377   1   1   0
# 38         0.0460        0.0408   1   1   0
# 438        0.4058        0.2808   0   0   0
# 456       -0.2255        0.1750   1   1   0
# 485        0.4894        0.4647   0   0   0
#
# [110 rows x 10 columns]

# %%
# Extract single tree
estimator_limited = rfc.estimators_[9]

from sklearn.tree import export_graphviz
export_graphviz(estimator_limited, out_file='tree_limited.dot', feature_names = X_train_NoName.columns,
                class_names = [str(i) for i in y_test.unique()],
                rounded = True, proportion = False, precision = 2, filled = True)

# %%
from IPython.display import Image
Image(filename = 'tree_limited.png')

# %%
from xgboost import XGBClassifier

# %%
xgbc = XGBClassifier()
xgbc.fit(X_train_NoName, y_train)
# Out:
# XGBClassifier(base_score=0.5, colsample_bylevel=1, colsample_bytree=1,
#        gamma=0, learning_rate=0.1, max_delta_step=0, max_depth=3,
#        min_child_weight=1, missing=None, n_estimators=100, nthread=-1,
#        objective='binary:logistic', reg_alpha=0, reg_lambda=1,
#        scale_pos_weight=1, seed=0, silent=True, subsample=1)

# %%
print('The accuracy of eXtreme Gradient Boosting Classifier on testing set:', xgbc.score(X_test_NoName, y_test))
# Out:
# The accuracy of eXtreme Gradient Boosting Classifier on testing set: 0.6829268292682927
