# %% [markdown]
# # Read Data

# %%
import csv
data = pd.read_csv('/Users/chenjessie/Desktop/5Factors.csv')
data = data.drop(columns=['Unnamed: 0'])
data
# Out:
#     Mkt-RF   SMB   HML   RMW   CMA    RF    Return
# 0     2.77  0.96  1.83  0.21  1.31  0.14  0.009245
# 1     1.44  0.32  6.71  1.97  3.55  0.18 -0.032787
# 2     6.93  0.37 -1.08  0.94 -0.38  0.18 -0.001488
# 3     1.10 -3.54 -4.07  0.93 -1.02  0.19  0.127517
# 4    -9.55 -3.05 -1.47 -0.13  0.16  0.19  0.143954
# 5     0.06 -2.52 -1.30  0.59  1.24  0.15 -0.103270
# 6     0.48  0.86 -2.38  0.71  0.33  0.14  0.202899
# 7    -2.35  3.54 -0.12 -0.51  0.00  0.12 -0.177172
# 8     1.06 -1.04  0.14  0.65  1.65  0.09  0.148728
# 9     2.51  4.84  3.03 -1.18  1.63  0.09 -0.151163
# 10    0.78  2.48  1.35 -2.01 -0.07  0.06  0.010067
# 11    0.17  0.78 -3.17  0.68 -1.00  0.03  0.008460
# 12    1.82  0.41  3.58  0.99 -0.30  0.03  0.092421
# 13    0.25  1.74 -1.49 -2.29 -0.08  0.02 -0.279627
# 14   -0.05  0.49 -1.47  1.19  1.92  0.02 -0.151412
# 15    6.96  1.10  1.16  0.81 -0.02  0.02 -0.292000
# 16   -2.17 -2.99 -2.59  0.31  0.13  0.01 -0.107143
# ...

# %% [markdown]
# # Split Data

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(data[['Mkt-RF','SMB','HML','RMW','CMA','RF']],data[['Return']],test_size=0.3,random_state=0)

# %% [markdown]
# # Find alpha

# %%
from sklearn.linear_model import LassoCV
lassocv = LassoCV()
lassocv.fit(x_train,y_train)
print(lassocv.alpha_)
print(lassocv.coef_)
# Out:
# 0.06256520053510795
# [-0.         -0.0102236   0.          0.          0.03208937  0.        ]
# /opt/anaconda3/envs/env1/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:1088: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %% [markdown]
# # Lasso

# %%
from sklearn.linear_model import Lasso
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
import random

    
lasso = Lasso(alpha=0.06256520053510795).fit(x_train,y_train)
y_train_pred = lasso.predict(x_train)
y_test_pred = lasso.predict(x_test)

mse_train = mean_squared_error(y_train,y_train_pred)
mse_test = mean_squared_error(y_test,y_test_pred)
r2_train = r2_score(y_train,y_train_pred)
r2_test = r2_score(y_test,y_test_pred)

print(lasso.coef_)
print("MSE_train: %.3f,MSE_test:%.3f"%( mse_train,mse_test ))
print("R^2_train: %.3f,R^2_test:%.3f"%( r2_train,r2_test ))
# Out:
# [-0.         -0.0102236   0.          0.          0.03208937  0.        ]
# MSE_train: 0.067,MSE_test:0.038
# R^2_train: 0.104,R^2_test:-0.402

# %% [markdown]
# # R squared is Negative

# %% [markdown]
# ![image](https://raw.githubusercontent.com/chenjanice/CTBC-PROJECT/master/HW3/images/r2.png)
